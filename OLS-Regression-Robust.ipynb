# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

main_df = pd.read_csv('cancer_reg.csv')
main_df
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medIncome  popEst2015  povertyPercent  studyPerCap  minIncome  \
# 0         61898      260131            11.2   499.748204    61494.5
# 1         48127       43269            18.6    23.111234    48021.6
# 2         49348       21026            14.6    47.560164    48021.6
# 3         44243       75882            17.1   342.637253    42724.4
# 4         49955       10321            12.5     0.000000    48021.6
# ...         ...         ...             ...          ...        ...
# 3042      46961        6343            12.4     0.000000    45201.0
# 3043      48609       37118            18.8   377.175494    48021.6
# 3044      51144       34536            15.0  1968.959926    51046.4
# 3045      50745       25609            13.3     0.000000    48021.6
# 3046      41193       37030            13.9     0.000000    40362.7
#
#       maxIncome  ...  PctPrivateCoverageAlone  PctEmpPrivCoverage  \
# 0      125635.0  ...                      0.0                41.6
# 1       51046.4  ...                     53.8                43.6
# 2       51046.4  ...                     43.5                34.9
# 3       45201.0  ...                     40.3                35.0
# 4       51046.4  ...                     43.9                35.1
# ...         ...  ...                      ...                 ...
# 3042    48021.6  ...                     54.9                44.6
# 3043    51046.4  ...                     53.3                48.6
# 3044    54545.6  ...                     52.6                47.8
# 3045    51046.4  ...                     56.3                49.6
# 3046    42724.4  ...                     60.3                22.9
#
#       PctPublicCoverage PctPublicCoverageAlone   PctWhite   PctBlack  \
# 0                  32.9                   14.0  81.780529   2.594728
# 1                  31.1                   15.3  89.228509   0.969102
# 2                  42.1                   21.1  90.922190   0.739673
# 3                  45.3                   25.0  91.744686   0.782626
# 4                  44.0                   22.7  94.104024   0.270192
# ...                 ...                    ...        ...        ...
# 3042               31.7                   13.2  90.280811   3.837754
# 3043               28.8                   17.7  75.706245   2.326771
# 3044               26.6                   16.8  87.961629   2.313188
# 3045               29.5                   14.0  92.905681   1.176562
# 3046               25.1                   12.6  70.098132  16.590100
#
#       PctAsian  PctOtherRace  PctMarriedHouseholds  BirthRate
# 0     4.821857      1.843479             52.856076   6.118831
# 1     2.246233      3.741352             45.372500   4.333096
# 2     0.465898      2.747358             54.444868   3.729488
# 3     1.161359      1.362643             51.021514   4.603841
# 4     0.665830      0.492135             54.027460   6.796657
# ...        ...           ...                   ...        ...
# 3042  0.327613      1.700468             51.063830   7.773512
# 3043  4.044920     14.130288             52.007937   8.186470
# 3044  1.316472      5.680705             55.153949   7.809192
# 3045  0.244632      2.131790             58.484232   7.582938
# 3046  3.177753      1.356457             56.040242   8.981723
#
# [3047 rows x 35 columns]

# %%
main_df.fillna(0)
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medIncome  popEst2015  povertyPercent  studyPerCap  minIncome  \
# 0         61898      260131            11.2   499.748204    61494.5
# 1         48127       43269            18.6    23.111234    48021.6
# 2         49348       21026            14.6    47.560164    48021.6
# 3         44243       75882            17.1   342.637253    42724.4
# 4         49955       10321            12.5     0.000000    48021.6
# ...         ...         ...             ...          ...        ...
# 3042      46961        6343            12.4     0.000000    45201.0
# 3043      48609       37118            18.8   377.175494    48021.6
# 3044      51144       34536            15.0  1968.959926    51046.4
# 3045      50745       25609            13.3     0.000000    48021.6
# 3046      41193       37030            13.9     0.000000    40362.7
#
#       maxIncome  ...  PctPrivateCoverageAlone  PctEmpPrivCoverage  \
# 0      125635.0  ...                      0.0                41.6
# 1       51046.4  ...                     53.8                43.6
# 2       51046.4  ...                     43.5                34.9
# 3       45201.0  ...                     40.3                35.0
# 4       51046.4  ...                     43.9                35.1
# ...         ...  ...                      ...                 ...
# 3042    48021.6  ...                     54.9                44.6
# 3043    51046.4  ...                     53.3                48.6
# 3044    54545.6  ...                     52.6                47.8
# 3045    51046.4  ...                     56.3                49.6
# 3046    42724.4  ...                     60.3                22.9
#
#       PctPublicCoverage PctPublicCoverageAlone   PctWhite   PctBlack  \
# 0                  32.9                   14.0  81.780529   2.594728
# 1                  31.1                   15.3  89.228509   0.969102
# 2                  42.1                   21.1  90.922190   0.739673
# 3                  45.3                   25.0  91.744686   0.782626
# 4                  44.0                   22.7  94.104024   0.270192
# ...                 ...                    ...        ...        ...
# 3042               31.7                   13.2  90.280811   3.837754
# 3043               28.8                   17.7  75.706245   2.326771
# 3044               26.6                   16.8  87.961629   2.313188
# 3045               29.5                   14.0  92.905681   1.176562
# 3046               25.1                   12.6  70.098132  16.590100
#
#       PctAsian  PctOtherRace  PctMarriedHouseholds  BirthRate
# 0     4.821857      1.843479             52.856076   6.118831
# 1     2.246233      3.741352             45.372500   4.333096
# 2     0.465898      2.747358             54.444868   3.729488
# 3     1.161359      1.362643             51.021514   4.603841
# 4     0.665830      0.492135             54.027460   6.796657
# ...        ...           ...                   ...        ...
# 3042  0.327613      1.700468             51.063830   7.773512
# 3043  4.044920     14.130288             52.007937   8.186470
# 3044  1.316472      5.680705             55.153949   7.809192
# 3045  0.244632      2.131790             58.484232   7.582938
# 3046  3.177753      1.356457             56.040242   8.981723
#
# [3047 rows x 35 columns]

# %%
main_df.dtypes
# Out:
# avgAnnCount                float64
# avgDeathsPerYear             int64
# TARGET_deathRate           float64
# incidenceRate              float64
# medIncome                    int64
# popEst2015                   int64
# povertyPercent             float64
# studyPerCap                float64
# minIncome                  float64
# maxIncome                  float64
# MedianAge                  float64
# MedianAgeMale              float64
# MedianAgeFemale            float64
# Geography                   object
# AvgHouseholdSize           float64
# PercentMarried             float64
# PctNoHS18_24               float64
# PctHS18_24                 float64
# PctSomeCol18_24            float64
# PctBachDeg18_24            float64
# PctHS25_Over               float64
# PctBachDeg25_Over          float64
# PctEmployed16_Over         float64
# PctUnemployed16_Over       float64
# PctPrivateCoverage         float64
# PctPrivateCoverageAlone    float64
# PctEmpPrivCoverage         float64
# PctPublicCoverage          float64
# PctPublicCoverageAlone     float64
# PctWhite                   float64
# PctBlack                   float64
# PctAsian                   float64
# PctOtherRace               float64
# PctMarriedHouseholds       float64
# BirthRate                  float64
# dtype: object

# %%
# Convert int64 data types to float64

main_df['avgDeathsPerYear'] = main_df['avgDeathsPerYear'].astype(float)
main_df['medIncome'] = main_df['medIncome'].astype(float)
main_df['popEst2015'] = main_df['popEst2015'].astype(float)
main_df.dtypes
# Out:
# avgAnnCount                float64
# avgDeathsPerYear           float64
# TARGET_deathRate           float64
# incidenceRate              float64
# medIncome                  float64
# popEst2015                 float64
# povertyPercent             float64
# studyPerCap                float64
# minIncome                  float64
# maxIncome                  float64
# MedianAge                  float64
# MedianAgeMale              float64
# MedianAgeFemale            float64
# Geography                   object
# AvgHouseholdSize           float64
# PercentMarried             float64
# PctNoHS18_24               float64
# PctHS18_24                 float64
# PctSomeCol18_24            float64
# PctBachDeg18_24            float64
# PctHS25_Over               float64
# PctBachDeg25_Over          float64
# PctEmployed16_Over         float64
# PctUnemployed16_Over       float64
# PctPrivateCoverage         float64
# PctPrivateCoverageAlone    float64
# PctEmpPrivCoverage         float64
# PctPublicCoverage          float64
# PctPublicCoverageAlone     float64
# PctWhite                   float64
# PctBlack                   float64
# PctAsian                   float64
# PctOtherRace               float64
# PctMarriedHouseholds       float64
# BirthRate                  float64
# dtype: object

# %%
# Assign X (data) and y (target)

X = main_df[['avgAnnCount', 'avgDeathsPerYear', 'incidenceRate', 'medIncome', 'popEst2015', 'povertyPercent', 'studyPerCap', 'minIncome', 'maxIncome', 'MedianAge', 'MedianAgeMale', 'MedianAgeFemale', 'AvgHouseholdSize', 'PercentMarried', 'PctNoHS18_24', 'PctHS18_24', 'PctSomeCol18_24', 'PctBachDeg18_24', 'PctHS25_Over', 'PctBachDeg25_Over', 'PctEmployed16_Over', 'PctUnemployed16_Over', 'PctPrivateCoverage', 'PctPrivateCoverageAlone', 'PctEmpPrivCoverage', 'PctPublicCoverage', 'PctPublicCoverageAlone', 'PctWhite', 'PctBlack', 'PctAsian', 'PctOtherRace', 'PctMarriedHouseholds', 'BirthRate']]
y = main_df["TARGET_deathRate"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (3047, 33) (3047, 1)

# %%
import statsmodels.formula.api as sm
 
result = sm.ols(formula="TARGET_deathRate ~ avgAnnCount + avgDeathsPerYear + incidenceRate + medIncome + popEst2015 + povertyPercent + studyPerCap + minIncome + maxIncome + MedianAge + MedianAgeMale + MedianAgeFemale + AvgHouseholdSize + PercentMarried + PctNoHS18_24 + PctHS18_24 + PctSomeCol18_24 + PctBachDeg18_24 + PctHS25_Over + PctBachDeg25_Over + PctEmployed16_Over + PctUnemployed16_Over + PctPrivateCoverage + PctPrivateCoverageAlone + PctEmpPrivCoverage + PctPublicCoverage + PctPublicCoverageAlone + PctWhite + PctBlack + PctAsian + PctOtherRace + PctMarriedHouseholds + BirthRate", data=main_df).fit(cov_type='HC1')

print(result.params)
# Out:
# Intercept                  158.531138
# avgAnnCount                 -0.003625
# avgDeathsPerYear             0.020452
# incidenceRate                0.193608
# medIncome                    0.000186
# popEst2015                  -0.000017
# povertyPercent               0.122301
# studyPerCap                 -0.000029
# minIncome                   -0.000592
# maxIncome                    0.000081
# MedianAge                   -0.003307
# MedianAgeMale               -0.503315
# MedianAgeFemale             -0.045035
# AvgHouseholdSize             0.408253
# PercentMarried               0.825763
# PctNoHS18_24                -0.122353
# PctHS18_24                   0.241670
# PctSomeCol18_24             -0.004238
# PctBachDeg18_24             -0.139149
# PctHS25_Over                 0.345979
# PctBachDeg25_Over           -1.289975
# PctEmployed16_Over          -0.052008
# PctUnemployed16_Over         0.320774
# PctPrivateCoverage          -0.364499
# PctPrivateCoverageAlone     -0.007199
# PctEmpPrivCoverage           0.283369
# PctPublicCoverage           -0.100395
# PctPublicCoverageAlone       0.220200
# PctWhite                    -0.142741
# PctBlack                    -0.085844
# PctAsian                    -0.120209
# PctOtherRace                -0.877453
# PctMarriedHouseholds        -0.910640
# BirthRate                   -0.877493
# dtype: float64

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       TARGET_deathRate   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     95.15
# Date:                Wed, 26 May 2021   Prob (F-statistic):               0.00
# Time:                        23:05:16   Log-Likelihood:                -13314.
# No. Observations:                3047   AIC:                         2.670e+04
# Df Residuals:                    3013   BIC:                         2.690e+04
# Df Model:                          33
# Covariance Type:                  HC1
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 158.5311     18.126      8.746      0.000     123.005     194.058
# avgAnnCount                -0.0036      0.001     -3.945      0.000      -0.005      -0.002
# avgDeathsPerYear            0.0205      0.004      5.669      0.000       0.013       0.028
# incidenceRate               0.1936      0.012     16.587      0.000       0.171       0.216
# medIncome                   0.0002      0.000      1.758      0.079   -2.14e-05       0.000
# popEst2015              -1.701e-05   5.07e-06     -3.352      0.001    -2.7e-05   -7.06e-06
# povertyPercent              0.1223      0.218      0.562      0.574      -0.305       0.549
# studyPerCap             -2.855e-05      0.001     -0.040      0.968      -0.001       0.001
# minIncome                  -0.0006      0.000     -5.141      0.000      -0.001      -0.000
# maxIncome                 8.14e-05   2.81e-05      2.896      0.004    2.63e-05       0.000
# MedianAge                  -0.0033      0.009     -0.373      0.709      -0.021       0.014
# MedianAgeMale              -0.5033      0.288     -1.747      0.081      -1.068       0.061
# MedianAgeFemale            -0.0450      0.271     -0.166      0.868      -0.577       0.487
# AvgHouseholdSize            0.4083      1.124      0.363      0.716      -1.795       2.611
# PercentMarried              0.8258      0.213      3.881      0.000       0.409       1.243
# PctNoHS18_24               -0.1224      0.069     -1.765      0.078      -0.258       0.014
# PctHS18_24                  0.2417      0.059      4.084      0.000       0.126       0.358
# PctSomeCol18_24            -0.0042      0.018     -0.231      0.818      -0.040       0.032
# PctBachDeg18_24            -0.1391      0.135     -1.032      0.302      -0.403       0.125
# PctHS25_Over                0.3460      0.115      3.012      0.003       0.121       0.571
# PctBachDeg25_Over          -1.2900      0.176     -7.311      0.000      -1.636      -0.944
# PctEmployed16_Over         -0.0520      0.026     -1.965      0.049      -0.104      -0.000
# PctUnemployed16_Over        0.3208      0.200      1.607      0.108      -0.070       0.712
# PctPrivateCoverage         -0.3645      0.173     -2.102      0.036      -0.704      -0.025
# PctPrivateCoverageAlone    -0.0072      0.016     -0.450      0.653      -0.039       0.024
# PctEmpPrivCoverage          0.2834      0.127      2.227      0.026       0.034       0.533
# PctPublicCoverage          -0.1004      0.263     -0.382      0.703      -0.616       0.415
# PctPublicCoverageAlone      0.2202      0.341      0.646      0.519      -0.448       0.889
# PctWhite                   -0.1427      0.081     -1.757      0.079      -0.302       0.016
# PctBlack                   -0.0858      0.079     -1.081      0.280      -0.242       0.070
# PctAsian                   -0.1202      0.255     -0.472      0.637      -0.619       0.379
# PctOtherRace               -0.8775      0.153     -5.716      0.000      -1.178      -0.577
# PctMarriedHouseholds       -0.9106      0.178     -5.102      0.000      -1.260      -0.561
# BirthRate                  -0.8775      0.257     -3.417      0.001      -1.381      -0.374
# ==============================================================================
# Omnibus:                      197.677   Durbin-Watson:                   1.778
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              835.080
# Skew:                           0.146   Prob(JB):                    4.62e-182
# Kurtosis:                       5.548   Cond. No.                     1.43e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# [2] The condition number is large, 1.43e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.metrics import mean_squared_error
import math

y_pred = result.predict(X)
 
MSE = mean_squared_error(y, y_pred)
 
RMSE = math.sqrt(MSE)

print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 19.120563137443988

# %%
from scipy import stats

def normality_of_residuals_test(result):
    '''
    Function for running 4 statistical tests to 
    investigate the normality of residuals.
    
    Arg:
    * model - fitted OLS models from statsmodels
    '''
    jb = stats.jarque_bera(result.resid)
    sw = stats.shapiro(result.resid)
    ad = stats.anderson(result.resid, dist='norm')
    ks = stats.kstest(result.resid, 'norm')
    
    print(f'Jarque-Bera test ---- statistic: {jb[0]:.4f}, p-value: {jb[1]}')
    print(f'Shapiro-Wilk test ---- statistic: {sw[0]:.4f}, p-value: {sw[1]:.4f}')
    print(f'Kolmogorov-Smirnov test ---- statistic: {ks.statistic:.4f}, p-value: {ks.pvalue:.4f}')
    print(f'Anderson-Darling test ---- statistic: {ad.statistic:.4f}, 5% critical value: {ad.critical_values[2]:.4f}')
    print('If the returned AD statistic is larger than the critical value, then for the 5% significance level, the null hypothesis that the data come from the Normal distribution should be rejected. ')
    
normality_of_residuals_test(result)
# Out:
# Jarque-Bera test ---- statistic: 835.0803, p-value: 0.0
# Shapiro-Wilk test ---- statistic: 0.9781, p-value: 0.0000
# Kolmogorov-Smirnov test ---- statistic: 0.4345, p-value: 0.0000
# Anderson-Darling test ---- statistic: 12.5080, 5% critical value: 0.7860
# If the returned AD statistic is larger than the critical value, then for the 5% significance level, the null hypothesis that the data come from the Normal distribution should be rejected.

# %%
import seaborn as sn
from matplotlib.pyplot import figure

figure(figsize=(16, 16), dpi=80)

corr_df = X.corr(method='pearson')
print("-----------------------------------------------Create A Correlation Plot---------------------------------------------------")

mask = np.zeros_like(corr_df)
mask[np.triu_indices_from(mask)] = True

sn.heatmap(corr_df, cmap='RdYlGn_r', vmax=1.0, vmin=-1.0, mask = mask, linewidths=2.5)

plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()

# corrMatrix = X.corr()
# sn.heatmap(corrMatrix, annot=True)
# plt.show()
# Out:
# -----------------------------------------------Create A Correlation Plot---------------------------------------------------

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
   
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#                     feature         VIF
# 0               avgAnnCount   11.511960
# 1          avgDeathsPerYear   35.919627
# 2             incidenceRate   85.556419
# 3                 medIncome  231.452063
# 4                popEst2015   29.070004
# 5            povertyPercent   49.913992
# 6               studyPerCap    1.140694
# 7                 minIncome  155.451225
# 8                 maxIncome   26.496093
# 9                 MedianAge    2.049581
# 10            MedianAgeMale  563.131397
# 11          MedianAgeFemale  674.650691
# 12         AvgHouseholdSize   44.724921
# 13           PercentMarried  482.548514
# 14             PctNoHS18_24    9.886288
# 15               PctHS18_24   25.925934
# 16          PctSomeCol18_24    1.356089
# 17          PctBachDeg18_24    5.656592
# 18             PctHS25_Over   90.897454
# 19        PctBachDeg25_Over   36.585390
# 20       PctEmployed16_Over   18.081006
# 21     PctUnemployed16_Over   15.281429
# 22       PctPrivateCoverage  540.216582
# 23  PctPrivateCoverageAlone    5.046779
# 24       PctEmpPrivCoverage  154.958472
# 25        PctPublicCoverage  533.433195
# 26   PctPublicCoverageAlone  238.607378
# 27                 PctWhite  180.986425
# 28                 PctBlack    6.968939
# 29                 PctAsian    2.430290
# 30             PctOtherRace    1.893359
# 31     PctMarriedHouseholds  436.747939
# 32                BirthRate   10.750112
