# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

main_df = pd.read_csv('cancer_reg.csv')
main_df
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medIncome  popEst2015  povertyPercent  studyPerCap  minIncome  \
# 0         61898      260131            11.2   499.748204    61494.5
# ...

# %%
main_df.fillna(0)
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# ...           ...               ...               ...            ...
# 3042  1962.667684                15             149.6     453.549422
# 3043  1962.667684                43             150.1     453.549422
# 3044  1962.667684                46             153.9     453.549422
# 3045  1962.667684                52             175.0     453.549422
# 3046  1962.667684                48             213.6     453.549422
#
#       medIncome  popEst2015  povertyPercent  studyPerCap  minIncome  \
# 0         61898      260131            11.2   499.748204    61494.5
# ...

# %%
main_df.dtypes
# Out:
# avgAnnCount                float64
# avgDeathsPerYear             int64
# TARGET_deathRate           float64
# incidenceRate              float64
# medIncome                    int64
# popEst2015                   int64
# povertyPercent             float64
# studyPerCap                float64
# minIncome                  float64
# maxIncome                  float64
# MedianAge                  float64
# MedianAgeMale              float64
# MedianAgeFemale            float64
# Geography                   object
# AvgHouseholdSize           float64
# PercentMarried             float64
# PctNoHS18_24               float64
# PctHS18_24                 float64
# PctSomeCol18_24            float64
# PctBachDeg18_24            float64
# PctHS25_Over               float64
# PctBachDeg25_Over          float64
# PctEmployed16_Over         float64
# PctUnemployed16_Over       float64
# PctPrivateCoverage         float64
# PctPrivateCoverageAlone    float64
# PctEmpPrivCoverage         float64
# ...

# %%
# Convert int64 data types to float64

main_df['avgDeathsPerYear'] = main_df['avgDeathsPerYear'].astype(float)
main_df['medIncome'] = main_df['medIncome'].astype(float)
main_df['popEst2015'] = main_df['popEst2015'].astype(float)
main_df.dtypes
# Out:
# avgAnnCount                float64
# avgDeathsPerYear           float64
# TARGET_deathRate           float64
# incidenceRate              float64
# medIncome                  float64
# popEst2015                 float64
# povertyPercent             float64
# studyPerCap                float64
# minIncome                  float64
# maxIncome                  float64
# MedianAge                  float64
# MedianAgeMale              float64
# MedianAgeFemale            float64
# Geography                   object
# AvgHouseholdSize           float64
# PercentMarried             float64
# PctNoHS18_24               float64
# PctHS18_24                 float64
# PctSomeCol18_24            float64
# PctBachDeg18_24            float64
# PctHS25_Over               float64
# PctBachDeg25_Over          float64
# PctEmployed16_Over         float64
# PctUnemployed16_Over       float64
# PctPrivateCoverage         float64
# PctPrivateCoverageAlone    float64
# PctEmpPrivCoverage         float64
# ...

# %%
# Assign X (data) and y (target)

X = main_df[['avgAnnCount', 'avgDeathsPerYear', 'incidenceRate', 'medIncome', 'popEst2015', 'povertyPercent', 'MedianAgeMale', 'AvgHouseholdSize', 'PercentMarried', 'PctHS18_24', 'PctHS25_Over', 'PctBachDeg25_Over', 'PctUnemployed16_Over', 'PctEmpPrivCoverage', 'PctPublicCoverageAlone', 'PctOtherRace', 'PctMarriedHouseholds', 'BirthRate']]
y = main_df["TARGET_deathRate"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (3047, 18) (3047, 1)

# %%
import statsmodels.api as sm

mod_wls = sm.WLS(y, X, weights=1./18)
res_wls = mod_wls.fit()

# %%
print(res_wls.summary())
# Out:
#                                  WLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.988
# Model:                            WLS   Adj. R-squared (uncentered):              0.988
# Method:                 Least Squares   F-statistic:                          1.424e+04
# Date:                Thu, 27 May 2021   Prob (F-statistic):                        0.00
# Time:                        01:50:34   Log-Likelihood:                         -13381.
# No. Observations:                3047   AIC:                                  2.680e+04
# Df Residuals:                    3029   BIC:                                  2.691e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import mean_squared_error
import math

y_pred = res_wls.predict(X)
 
MSE = mean_squared_error(y, y_pred)
 
RMSE = math.sqrt(MSE)

print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 19.542241682567884

# %%
from scipy import stats

def normality_of_residuals_test(res_wls):
    '''
    Function for running 4 statistical tests to 
    investigate the normality of residuals.
    
    Arg:
    * model - fitted OLS models from statsmodels
    '''
    jb = stats.jarque_bera(res_wls.resid)
    sw = stats.shapiro(res_wls.resid)
    ad = stats.anderson(res_wls.resid, dist='norm')
    ks = stats.kstest(res_wls.resid, 'norm')
    
    print(f'Jarque-Bera test ---- statistic: {jb[0]:.4f}, p-value: {jb[1]}')
    print(f'Shapiro-Wilk test ---- statistic: {sw[0]:.4f}, p-value: {sw[1]:.4f}')
    print(f'Kolmogorov-Smirnov test ---- statistic: {ks.statistic:.4f}, p-value: {ks.pvalue:.4f}')
    print(f'Anderson-Darling test ---- statistic: {ad.statistic:.4f}, 5% critical value: {ad.critical_values[2]:.4f}')
    print('If the returned AD statistic is larger than the critical value, then for the 5% significance level, the null hypothesis that the data come from the Normal distribution should be rejected. ')
    
normality_of_residuals_test(res_wls)
# Out:
# Jarque-Bera test ---- statistic: 814.6959, p-value: 0.0
# Shapiro-Wilk test ---- statistic: 0.9788, p-value: 0.0000
# Kolmogorov-Smirnov test ---- statistic: 0.4412, p-value: 0.0000
# Anderson-Darling test ---- statistic: 11.0792, 5% critical value: 0.7860
# If the returned AD statistic is larger than the critical value, then for the 5% significance level, the null hypothesis that the data come from the Normal distribution should be rejected.

# %%
import seaborn as sn
from matplotlib.pyplot import figure

figure(figsize=(16, 16), dpi=80)

corr_df = X.corr(method='pearson')
print("-----------------------------------------------Create A Correlation Plot---------------------------------------------------")

mask = np.zeros_like(corr_df)
mask[np.triu_indices_from(mask)] = True

sn.heatmap(corr_df, cmap='RdYlGn_r', vmax=1.0, vmin=-1.0, mask = mask, linewidths=2.5, annot=True)

plt.yticks(rotation=0)
plt.xticks(rotation=90)
plt.show()
# Out:
# -----------------------------------------------Create A Correlation Plot---------------------------------------------------

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
   
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#                    feature         VIF
# 0              avgAnnCount   11.257777
# 1         avgDeathsPerYear   35.016124
# 2            incidenceRate   76.966773
# 3                medIncome   94.466243
# 4               popEst2015   28.071874
# 5           povertyPercent   35.962044
# 6            MedianAgeMale  113.837423
# 7         AvgHouseholdSize   43.641478
# 8           PercentMarried  441.083757
# 9               PctHS18_24   22.438055
# 10            PctHS25_Over   82.456209
# 11       PctBachDeg25_Over   28.660073
# 12    PctUnemployed16_Over   14.200785
# 13      PctEmpPrivCoverage   71.334886
# 14  PctPublicCoverageAlone   46.141243
# 15            PctOtherRace    1.714712
# 16    PctMarriedHouseholds  391.726022
# 17               BirthRate   10.135713
